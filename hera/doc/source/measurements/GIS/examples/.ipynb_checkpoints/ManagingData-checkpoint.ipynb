# %% [markdown]
# # Managing Data
#
# Here we will give examples of managing GIS data.

# %%
import matplotlib.pyplot as plt
from hera import GIS

datalayer = GIS.GIS_datalayer(projectName = "Examples", FilesDirectory = "/home/ofir/tmp/BNTL-HAIFA")

# %% [markdown]
# The GIS_datahandler class helps managing GIS data.
# The class requires a project name and a directory path in which to save new files.
#
# ## Getting and adding Data
#
# Getting data is done using a function called getGISdata.
# This function may load existing data, or add new data if the requested data isn't available.
#
# In order to create a new file and a corresponding document in the database,
# two parameters must be given to the function.
# The first is called points, and it holds the ITM coordinates of a rectangle.
# It is a list, from the structure [minimum x, minimum y, maximum x, maximum y].
# The second is called CutName, and it is used as part of the new file's name.
#
# Any other parameters can be given as descriptors of the data.
# In the next example a parameter named Region is defined.

# %%
points = [193000, 731000, 218500, 763000]
example_data = datalayer.getGISDocuments(points=points, CutName="Example", Region="Haifa")
example_data
# Out:
# [<Measurements: Measurements object>]

# %% [markdown]
# The function retruns a list of documents. Throughout the rest of the tutorial, we would use the data achieved by getData().

# %%
example_data = example_data[0].getData()
example_data[:10]
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /home/ofir/tmp/BNTL-HAIFA//ExamplesExample-Contour.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-4-1bc2abd7a233> in <module>
# ----> 1 example_data = example_data[0].getData()
#
# ~/Development/Hera/hera/datalayer/document/metadataDocument.py in getData(self, **kwargs)
#      29             object according to the datahandler.
#      30         """
# ---> 31         return getHandler(self.dataFormat).getData(self.resource, **kwargs)
#      32
#      33
#
# ~/Development/Hera/hera/datalayer/datahandler.py in getData(resource)
#     135     @staticmethod
#     136     def getData(resource):
# --> 137         df = geopandas.read_file(resource)
#     138
#     139         return df
#
# ~/anaconda3/lib/python3.7/site-packages/geopandas/io/file.py in read_file(filename, bbox, mask, rows, **kwargs)
#      87
#      88     with fiona_env():
# ---> 89         with reader(path_or_bytes, **kwargs) as features:
#      90
#      91             # In a future Fiona release the crs attribute of features will
#
# ~/anaconda3/lib/python3.7/site-packages/fiona/env.py in wrapper(*args, **kwargs)
#     396     def wrapper(*args, **kwargs):
#     397         if local._env:
# --> 398             return f(*args, **kwargs)
#     399         else:
#     400             if isinstance(args[0], str):
#
# ~/anaconda3/lib/python3.7/site-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     252         if mode in ('a', 'r'):
#     253             c = Collection(path, mode, driver=driver, encoding=encoding,
# --> 254                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     255         elif mode == 'w':
#     256             if schema:
#
# ~/anaconda3/lib/python3.7/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     152             if self.mode == 'r':
#     153                 self.session = Session()
# --> 154                 self.session.start(self, **kwargs)
#     155             elif self.mode in ('a', 'w'):
#     156                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: /home/ofir/tmp/BNTL-HAIFA//ExamplesExample-Contour.shp: No such file or directory

# %% [markdown]
# The data is loaded as a geopandas dataframe.
#
# Now that the new project contains data, the data can be loaded by addressing its descriptors.
# Using the getGISdata without any parameters will return all the documents in the project.
# In the next example, we will load all the data that holds the region Haifa.

# %%
example_data = datalayer.getGISDocuments(Region="Haifa")[0].getData()
example_data[:10]
# Out:
#    FCODE  FTYPE  HEIGHT      ORIG_LEN    SHAPE_Leng  \
# 0    611     10       0  19938.695735  19938.695735
# 1    611     10       0     42.973966     42.973966
# 2    611     10       0     86.598621     86.598621
# 3    611     11       5  33452.888982  33452.888982
# 4    611     11       5    380.349931    380.349931
# 5    611     11       5    129.627380    129.627380
# 6    611     11       5     12.104079     12.104079
# 7    611     11       5    100.395797    100.395797
# 8    611     11       5     54.094820     54.094820
# 9    611     11       5     63.664270     63.664270
#
#                                             geometry
# 0  LINESTRING (207394.358 763000.000, 207392.793 ...
# 1  LINESTRING (207161.130 760600.113, 207160.685 ...
# 2  LINESTRING (207363.937 760392.098, 207366.788 ...
# 3  LINESTRING (195706.140 740000.000, 195699.475 ...
# 4  LINESTRING (207060.154 740000.000, 207064.209 ...
# 5  LINESTRING (207004.017 739924.000, 207002.902 ...
# 6  LINESTRING (208512.131 740000.000, 208508.487 ...
# 7  LINESTRING (206933.499 739797.454, 206932.739 ...
# 8  LINESTRING (207074.941 739808.000, 207073.838 ...
# 9  LINESTRING (207287.833 739771.791, 207287.640 ...

# %% [markdown]
# If we would write a region that doesn't appear in the database we will get an error,
# and the program would ask for points and a CutName for the new data.

# %%
example_data = datalayer.getGISDocuments(Region="haifa")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-a76b44bb84cf> in <module>
# ----> 1 example_data = dataHandler.getGISData(Region="haifa")
#
# ~/Development/pyhera/hera/measurements/GIS/analytics/GISdatahandler.py in getGISData(self, points, CutName, mode, GeometryMode, Geometry, **kwargs)
#      55             else:
#      56                 if points == None or CutName == None:
# ---> 57                     raise KeyError("Could not find data. Please insert points and CutName for making new data.")
#      58                 else:
#      59                     self._datalayer.makeData(points=points, CutName=CutName, mode=mode, additional_data=kwargs)
#
# KeyError: 'Could not find data. Please insert points and CutName for making new data.'

# %% [markdown]
# ## GIS Data Types
#
# The data we have loaded so far contains contour lines.
# The data can be easily plotted, as demonstrated below.

# %%
example_data.plot()
plt.show()

# %% [markdown]
# The contour lines data is the default data mode.
# The package supports two more types of data, which present buildings and roads.
# The two data types are presented below.

# %%
points = [193000, 735000, 218500, 760000]
example_buildings = datalayer.getGISDocuments(points=points, CutName="Example", Region="Haifa", mode="Buildings")[0].getData()
example_roads = datalayer.getGISDocuments(points=points, CutName="Example", Region="Haifa", mode="Roads").getData()
example_buildings.plot()
example_roads.plot()
plt.show()

# %% [markdown]
# The data type is saved as one of the descriptors, called 'mode', and can be used for querying data.
# In the next example we would load all the contour data in the project.

# %%
example_contour = datalayer.getGISDocuments(mode="Contour").getData()
example_contour[:10]
# Out:
#    FCODE  FTYPE  HEIGHT      ORIG_LEN    SHAPE_Leng  \
# 0    611     10       0  19938.695735  19938.695735
# 1    611     10       0     42.973966     42.973966
# 2    611     10       0     86.598621     86.598621
# 3    611     11       5  33452.888982  33452.888982
# 4    611     11       5    380.349931    380.349931
# 5    611     11       5    129.627380    129.627380
# 6    611     11       5     12.104079     12.104079
# 7    611     11       5    100.395797    100.395797
# 8    611     11       5     54.094820     54.094820
# 9    611     11       5     63.664270     63.664270
#
#                                             geometry
# 0  LINESTRING (207394.358 763000.000, 207392.793 ...
# 1  LINESTRING (207161.130 760600.113, 207160.685 ...
# 2  LINESTRING (207363.937 760392.098, 207366.788 ...
# 3  LINESTRING (195706.140 740000.000, 195699.475 ...
# 4  LINESTRING (207060.154 740000.000, 207064.209 ...
# 5  LINESTRING (207004.017 739924.000, 207002.902 ...
# 6  LINESTRING (208512.131 740000.000, 208508.487 ...
# 7  LINESTRING (206933.499 739797.454, 206932.739 ...
# 8  LINESTRING (207074.941 739808.000, 207073.838 ...
# 9  LINESTRING (207287.833 739771.791, 207287.640 ...

# %% [markdown]
# ## Managing Geometry Shapes Database
#
# Other kinds of data that are usefull to save in the database are points and polygons.
# It is usefull to save the coordinates of known locations such as cities or points of interest.
#
# In order to add a new location to the database, use the addGeometry function.
# The function must receive an unused name for the new location, and the location itself.
#
# A point can be induced either as a shapely.geometry.Point or a list.

# %%
from shapely import geometry

Haifa_Port = geometry.Point([200000,748000])
# Haifa_Port = [200000,748000] this syntax would work as well.

datalayer.addGeometry(name="Haifa_Port", Geometry=Haifa_Port)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-3e7e61daa007> in <module>
#       4 # Haifa_Port = [200000,748000] this syntax would work as well.
#       5
# ----> 6 dataHandler.addGeometry(name="Haifa_Port", Geometry=Haifa_Port)
#
# ~/Development/pyhera/hera/measurements/GIS/analytics/GISdatahandler.py in addGeometry(self, Geometry, name)
#      69                         "list of x coordinates and y coordinates ([[x1,x2,...],[y1,y2,...]])"
#      70         if check:
# ---> 71             raise KeyError("Name is already used.")
#      72         else:
#      73             if type(Geometry)==geometry.polygon.Polygon:
#
# KeyError: 'Name is already used.'

# %% [markdown]
# A polygon can be induced either as a shapely.geometry.Polygon, a list of points or a list of x coordinated and y coordinates.

# %%
Bahai_Gardens = geometry.Polygon([[199220,747015],[199333,746947],[198957,746277],[198779,746438]])
# Bahai_Gardens = [[199220,747015],[199333,746947],[198957,746277],[198779,746438]] this syntax would work as well.
# Bahai_Gardens = [[199220,199333,198957,198779],[747015,746947,746277,746438]] this syntax would work as well.

datalayer.addGeometry(name="Bahai_Gardens", Geometry=Bahai_Gardens)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e04fb1f617b5> in <module>
#       3 # Bahai_Gardens = [[199220,199333,198957,198779],[747015,746947,746277,746438]] this syntax would work as well.
#       4
# ----> 5 dataHandler.addGeometry(name="Bahai_Gardens", Geometry=Bahai_Gardens)
#
# ~/Development/pyhera/hera/measurements/GIS/analytics/GISdatahandler.py in addGeometry(self, Geometry, name)
#      69                         "list of x coordinates and y coordinates ([[x1,x2,...],[y1,y2,...]])"
#      70         if check:
# ---> 71             raise KeyError("Name is already used.")
#      72         else:
#      73             if type(Geometry)==geometry.polygon.Polygon:
#
# KeyError: 'Name is already used.'

# %% [markdown]
# The locations can be loaded using another function by addressing their names.

# %%
type(datalayer.getGeometry(name="Haifa_Port"))
# Out:
# shapely.geometry.point.Point

# %% [markdown]
# The location's coordinates and type of shapely geometry may also be loaded.

# %%
points, geometry_type = datalayer.getGeometryPoints("Bahai_Gardens")
print("points: %s, geometry type: %s" % (points, geometry_type))
# Out:
# points: [[199220.0, 747015.0], [199333.0, 746947.0], [198957.0, 746277.0], [198779.0, 746438.0], [199220.0, 747015.0]], geometry type: Polygon

# %% [markdown]
# ## Loading images
#
# Images can be loaded to the database using the next method:

# %%
path = "/home/ofir/Projects/2020/GIS/Haifa.png" # The image's path
location = "Haifa" # The image's location
extents = [193000, 218500,731000,763000] # coordinates [left, right, bottom, up]

datalayer.loadImage(path=path, locationName=location, extents=extents)

# %% [markdown]
# ## Geometrical Queries
#
# The data can also be querried by geometrical properties.
# The default type of querries check if a certain geometry lies entirely within existing datas.
# For example, we would define a line that lies entirely within the rectangle of the contour data but some of it is outside the bounds of the other data types.
# The query would return only the contour data.
#
# The query is done by addressing a parameter called 'geometry'.

# %%
line = geometry.LineString([(200000, 740000), (200000, 733000)])
example_contain = datalayer.getGISDocuments(Geometry=line)[0].getData()
example_contain.plot()
plt.plot([200000,200000],[733000,740000], color="black")
plt.show()

# %% [markdown]
# Another kind of geometrical queries return all the data that intersects with the defined geometry.
# It is defined by a parameter called 'GeometryMode'.
# The line intersects with all the data types we had saved in the database.
# Therefore, all the data should be returned.

# %%
example_intersect = datalayer.getGISDocuments(Geometry=line, GeometryMode="intersects")[0].getData()
for example in example_intersect:
    example.plot()
    plt.plot([200000,200000],[733000,740000], color="black")
    plt.show()

# %% [markdown]
# In addition, a saved shapely geometry name can be given as the geometry.
# For example, in the next example all the data that contains Haifa's port is loaded.

# %%
contain_port = datalayer.getGISDocuments(Geometry="Haifa_Port")[0].getData()
for example in contain_port:
    fig, ax = plt.subplots(1,1)
    ax = example.plot()
    dataHandler.plotGeometry("Haifa_Port", ax=ax)
