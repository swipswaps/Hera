# %% [markdown]
# # Plotting existing shapes and images
#
# Here we will give examples of plotting existing shapes and images from the database.

# %%
import matplotlib.pyplot as plt
from hera import GIS

plotdata = GIS.Plotting(projectName = "Examples", FilesDirectory="/home/ofir/tmp/BNTL-HAIFA")

# %% [markdown]
# The GIS_datalayer class helps managing GIS data.
# The class requires a project name.
#
# ## Plot geometry shapes.
#
# Existing locations from the database may be plotted using a built in function.
#
# The default color for the locations is black, and the default marker for points is a star.
# They can be changed by setting the parameters "color" and "marker", the same as in plt.plot.

# %%
fig, ax = plt.subplots(1,1)
ax = example_roads.plot()
dataHandler.plotGeometry(names=["Haifa_Port", "Bahai_Gardens"], ax=ax)
plt.ylim(745000,750000)
plt.xlim(195000,203000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-57bc4ce18615> in <module>
#       1 fig, ax = plt.subplots(1,1)
# ----> 2 ax = example_roads.plot()
#       3 dataHandler.plotGeometry(names=["Haifa_Port", "Bahai_Gardens"], ax=ax)
#       4 plt.ylim(745000,750000)
#       5 plt.xlim(195000,203000)
#
# NameError: name 'example_roads' is not defined

# %% [markdown]
# ## Plot images
#
# Existing images from the database can also be plotted, using the naxt method:

# %%
location = "Haifa"
fig, ax = plt.subplots(1,1)

plotdata.plotImageLocation(locationName=location, ax=ax)
plt.show()

# %% [markdown]
# Any additional requirements for the image can be given as a dictionary for the parameter "query".
